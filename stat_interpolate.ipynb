# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
app = pd.read_csv('/content/drive/MyDrive/2022 fall DS440/data/APPL/AAPL_monthly_valuation_measures.csv')

# %%
app
# Out:
#                            name                ttm         08/26/2022  \
# 0                     MarketCap  2,629,496,442,240  2,629,496,442,240
# 1               EnterpriseValue  2,700,956,442,240  2,700,956,442,240
# 2                       PeRatio             27.045                NaN
# 3                ForwardPeRatio              25.84                NaN
# 4                      PegRatio              2.926                NaN
# 5                       PsRatio              6.947                NaN
# 6                       PbRatio             45.253                NaN
# 7  EnterprisesValueRevenueRatio              6.969                NaN
# 8   EnterprisesValueEBITDARatio             20.509                NaN
#
#           07/29/2022         06/30/2022         05/31/2022         04/29/2022  \
# 0  2,611,657,907,520  2,200,560,080,160  2,409,002,340,040  2,551,593,784,650
# 1  2,683,117,907,520  2,269,030,080,160  2,477,472,340,040  2,620,063,784,650
# ...

# %%
first = app.iloc[2,]
first = pd.DataFrame(first)
first = first.iloc[2:,[0]]
first.index.name = "Date"
first.columns = ['PeRatio']

# %%
first = first.reset_index(level=['Date'])
first
# Out:
#            Date PeRatio
# 0    08/26/2022     NaN
# 1    07/29/2022     NaN
# 2    06/30/2022  22.231
# 3    05/31/2022  24.202
# 4    04/29/2022     NaN
# ..          ...     ...
# 460  12/31/1985  18.964
# 461  11/29/1985     NaN
# 462  10/31/1985  18.627
# 463  09/30/1985  15.751
# 464  08/30/1985     NaN
#
# [465 rows x 2 columns]

# %%
first = first[['PeRatio']].apply(pd.to_numeric)

# %%
first
# Out:
#      PeRatio
# 0        NaN
# 1        NaN
# 2     22.231
# 3     24.202
# 4        NaN
# ..       ...
# 460   18.964
# 461      NaN
# 462   18.627
# 463   15.751
# 464      NaN
#
# [465 rows x 1 columns]

# %%
first.interpolate(method='values')
# Out:
#      PeRatio
# 0        NaN
# 1        NaN
# 2    22.2310
# 3    24.2020
# 4    26.5795
# ..       ...
# 460  18.9640
# 461  18.7955
# 462  18.6270
# 463  15.7510
# 464  15.7510
#
# [465 rows x 1 columns]

# %%
first.interpolate(method='linear',limit_direction='both')
# Out:
#      PeRatio
# 0    22.2310
# 1    22.2310
# 2    22.2310
# 3    24.2020
# 4    26.5795
# ..       ...
# 460  18.9640
# 461  18.7955
# 462  18.6270
# 463  15.7510
# 464  15.7510
#
# [465 rows x 1 columns]

# %%
first.interpolate(method='polynomial',order=3,limit_direction='both')
# Out:
#        PeRatio
# 0          NaN
# 1          NaN
# 2    22.231000
# 3    24.202000
# 4    27.565461
# ..         ...
# 460  18.964000
# 461  19.117920
# 462  18.627000
# 463  15.751000
# 464        NaN
#
# [465 rows x 1 columns]
